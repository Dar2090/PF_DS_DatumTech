# %% [markdown]
# ### Importamos las librerias necesarias para realizar nuestro ETL:

# %%
from pyspark.sql.functions import col, sum

# %% [markdown]
# ### Realizamos la conexion a ADLS para poder acceder a los archivos reviews-estados:

# %%
spark.conf.set("fs.azure.account.key.datumtechstorage.dfs.core.windows.net","2IEO7wL5cOzrt/r4jBQ8WnSRCq5LHWA3ezQ33eZYVsp1W9PI+53LPQ6bz56KFnEJKwsJEPZFtDPS+AStqxFgeA==")

# %% [markdown]
# ### Creacion de tabla `processed_files_user` para mantener el registro de los archivos ya procesados.

# %%
spark.sql("CREATE TABLE IF NOT EXISTS processed_files_user (file_name STRING) USING DELTA")

# %% [markdown]
# ### Obtenemos la lista de archivos en ADLS.

# %%
adls_files = dbutils.fs.ls("abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/Yelp/tip.json")
#display(adls_files)

# %% [markdown]
# ### Creamos un variable `new_files_user` que contiene los archivos que no estan en ADLS.

# %%
processed_files_user = spark.sql("SELECT file_name FROM processed_files_user").toPandas()["file_name"].tolist()

new_files_user = [file for file in adls_files if file.name not in processed_files_user]

# %% [markdown]
# ### Podemos ver que archivos ya estan procesados en la tabla `processed_files_user`

# %%
#spark.sql("SELECT * FROM processed_files_user").show()

# %% [markdown]
# ### Podemos ver que archivos no estan procesados aun.

# %%
print(new_files_user)
# Out:
# [FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Alabama/', name='review-Alabama/', size=0, modificationTime=1686171641000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Alaska/', name='review-Alaska/', size=0, modificationTime=1686171747000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Arizona/', name='review-Arizona/', size=0, modificationTime=1686173085000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Arkansas/', name='review-Arkansas/', size=0, modificationTime=1686173230000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-California/', name='review-California/', size=0, modificationTime=1686173422000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Colorado/', name='review-Colorado/', size=0, modificationTime=1686172195000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Connecticut/', name='review-Connecticut/', size=0, modificationTime=1686172383000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Delaware/', name='review-Delaware/', size=0, modificationTime=1686172557000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-District_of_Columbia/', name='review-District_of_Columbia/', size=0, modificationTime=1686172640000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Florida/', name='review-Florida/', size=0, modificationTime=1686172692000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Georgia/', name='review-Georgia/', size=0, modificationTime=1686172916000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Hawaii/', name='review-Hawaii/', size=0, modificationTime=1686191281000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Idaho/', name='review-Idaho/', size=0, modificationTime=1686191454000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Illinois/', name='review-Illinois/', size=0, modificationTime=1686191577000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Indiana/', name='review-Indiana/', size=0, modificationTime=1686191751000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Iowa/', name='review-Iowa/', size=0, modificationTime=1686191914000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Kansas/', name='review-Kansas/', size=0, modificationTime=1686192099000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Kentucky/', name='review-Kentucky/', size=0, modificationTime=1686192245000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Louisiana/', name='review-Louisiana/', size=0, modificationTime=1686192359000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Maine/', name='review-Maine/', size=0, modificationTime=1686192463000), FileInfo(path='abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Maryland/', name='review-Maryland/', size=0, modificationTime=1686192553000), FileInfo(path='abfss://datumcontainer@datumtechstorage.df ...

# %%
display(new_files_user)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Alabama/</td><td>review-Alabama/</td><td>0</td><td>1686171641000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Alaska/</td><td>review-Alaska/</td><td>0</td><td>1686171747000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Arizona/</td><td>review-Arizona/</td><td>0</td><td>1686173085000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Arkansas/</td><td>review-Arkansas/</td><td>0</td><td>1686173230000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-California/</td><td>review-California/</td><td>0</td><td>1686173422000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Colorado/</td><td>review-Colorado/</td><td>0</td><td>1686172195000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Connecticut/</td><td>review-Connecticut/</td><td>0</td><td>1686172383000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Delaware/</td><td>review-Delaware/</td><td>0</td><td>1686172557000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-District_of_Columbia/</td><td>review-District_of_Columbia/</td><td>0</td><td>1686172640000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Florida/</td><td>review-Florida/</td><td>0</td><td>1686172692000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Georgia/</td><td>review-Georgia/</td><td>0</td><td>1686172916000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Hawaii/</td><td>review-Hawaii/</td><td>0</td><td>1686191281000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Idaho/</td><td>review-Idaho/</td><td>0</td><td>1686191454000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Illinois/</td><td>review-Illinois/</td><td>0</td><td>1686191577000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Indiana/</td><td>review-Indiana/</td><td>0</td><td>1686191751000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Iowa/</td><td>review-Iowa/</td><td>0</td><td>1686191914000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Kansas/</td><td>review-Kansas/</td><td>0</td><td>1686192099000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Kentucky/</td><td>review-Kentucky/</td><td>0</td><td>1686192245000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Louisiana/</td><td>review-Louisiana/</td><td>0</td><td>1686192359000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Maine/</td><td>review-Maine/</td><td>0</td><td>1686192463000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/GoogleMaps/reviews-estados/review-Maryland/</td><td>review-Maryland/</td><td>0</td><td>1686192553000</td></tr><tr><td>abfss://datumcontainer@datumtechstorage. ...

# %%
#new_files_user[1][1].rstrip("/")

# %% [markdown]
# ### Creamos la funcion `etl` que realiza todo el proceso y devuelve el dataframe en formato parquet a la tabla silver corrrespondiente a los datos ya procesados.

# %%
def etl(file):
    
    # Definimos las rutas:
    path_raw=f"abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/Yelp/user.parquet{file}"
    path_bronze = f"abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/Bronze/YelpBronze/user-bronze/{file}-bronze.parquet"
    path_silver = f"abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/Silver/YelpSilver/user-Silver/{file}-silver.parquet"

    # Cargamos el archivo desde ADLS. Nos quedamos solo con las columnas consideradas para el proyecto:
    df_raw = spark.read.format("parquet").option("multiline", True).load(path_raw).select('user_id','average_stars')
     
    # Guardamos el DataFrame df_raw en la tabla bronze correspondiente a los datos en crudo o poco procesados en Azure Data Lake con un formato parquet ideal para manejar altos volumenes de datos.
    df_raw.write.format("parquet").save(path_bronze)
        
    # Cargamos el archivo desde la tabla bronze en Azure Data Lake en un DataFrame.
    df_user = spark.read.format("parquet").load(path_bronze)

    # Eliminamos duplicados
    df_user = df_user.dropDuplicates()

        
    # Eliminamos valores vacíos o nulos en las columnas 
    df_user = df_user.dropna()
    # Guardamos el DataFrame df_metadata en la tabla silver correspondiente a los datos procesados en Azure Data Lake.
    return df_user.write.format("parquet").save(path_silver)

# %% [markdown]
# ### Iteramos sobre cada archivo sin procesar.

# %%
for file in new_files_user:
    etl(file.name.rstrip("/"))

# %% [markdown]
# ### Agregamos a la tabla `processed_files_user` los archivos ya procesados.

# %%
new_files_df = spark.createDataFrame([(file.name,) for file in new_files_user], ["file_name"])
new_files_df.write.format("delta").mode("append").saveAsTable("processed_files_user")

# %% [markdown]
# ### Podemos verificar que, efectivamente esten registrados los archivos ya procesados.

# %%
spark.sql("SELECT * FROM processed_files_user").show()
# Out:
# +--------------------+
# |           file_name|
# +--------------------+
# | review-Mississippi/|
# |    review-Missouri/|
# |     review-Montana/|
# |    review-Nebraska/|
# |      review-Nevada/|
# |review-New_Hampsh...|
# |  review-New_Jersey/|
# |  review-New_Mexico/|
# |    review-New_York/|
# |review-North_Caro...|
# |review-North_Dakota/|
# |        review-Ohio/|
# |     review-Alabama/|
# |      review-Alaska/|
# |     review-Arizona/|
# |    review-Arkansas/|
# |  review-California/|
# |    review-Colorado/|
# | review-Connecticut/|
# |    review-Delaware/|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# #### Para comprobar que todo se haya ejecutado de manera correcta, podemos traer cualquier archivo de la tabla silver y hacer algunas verificaciones.

# %%
# Funcion para cargar el archivo desde la tabla correspondiente al estado de los datos en Azure Data Lake en un DataFrame.
'''def load_from(file, level):
    path= f"abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/{level}/GoogleMaps{level}/reviews-estados-{level}/{file}-{level.lower()}.parquet"
    df = spark.read.format("parquet").load(path)
    return df'''
# Out:
# Out[113]: 'def load_from(file, level):\n    path= f"abfss://datumcontainer@datumtechstorage.dfs.core.windows.net/{level}/GoogleMaps{level}/reviews-estados-{level}/{file}-{level.lower()}.parquet"\n    df = spark.read.format("parquet").load(path)\n    return df'

# %%
# Cambiando ...new_files[<valor de la fila en la tabla>][1]... podras cargar algun archivo de los ya procesados de la tabla silver.
#df = load_from(new_files[0][1].rstrip("/"), "Silver")

# %%
#display(df)

# %% [markdown]
# ### Podemos verificar si hay nulos en algun archivo en la tabla silver.

# %%
# Funcion para el conteo de nulos del dataframe.
'''def null_counts (df):
    counts = df.select([sum(col(c).isNull().cast("integer")).alias(c) for c in df.columns])
    return counts.show()'''
# Out:
# Out[116]: 'def null_counts (df):\n    counts = df.select([sum(col(c).isNull().cast("integer")).alias(c) for c in df.columns])\n    return counts.show()'

# %%
# Vemos que columnas poseen nulos y en que cantidad.
#nulls = null_counts(df)
